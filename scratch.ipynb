# %%
import pandas as pd
from pom_model.constants import VARY_TEMP, AEROBIC_LMWOM_GROWTH_EFFICIENCY, DEFAULT_MORTALITY, K_LMWOM
from pom_model.pom import init_model, run_model
PATCH = init_model(varTemp=VARY_TEMP, ymom=AEROBIC_LMWOM_GROWTH_EFFICIENCY, mortality=DEFAULT_MORTALITY, kmom=K_LMWOM)
UPDATED_PATCH= run_model(PATCH)
# Out:
# /var/folders/f3/zyvmf_xs32qbkl_h7913df540000gn/T/ipykernel_92949/3515135725.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# Step 0 starting
# Step 10 starting
# Step 20 starting
# Step 30 starting
# Step 40 starting
# Step 50 starting
# Step 60 starting
# Step 70 starting
# Step 80 starting
# Step 90 starting
# Step 100 starting
# Step 110 starting
# Step 120 starting
# Step 130 starting
# Step 140 starting
# Step 150 starting
# Step 160 starting
# Step 170 starting
# Step 180 starting
# Step 190 starting
# Step 200 starting
# Step 210 starting
# Step 220 starting
# Step 230 starting
# ...

# %%
UPDATED_PATCH
# Out:
# {'pom': array([1.23      , 0.65888131, 0.0671727 , 0.08266433, 0.09742314,
#         0.29437011, 0.11790091, 0.25497949, 0.13484163, 0.13940633,
#         0.14364794, 0.14758155, 0.1512242 , 0.1545941 , 0.15771005,
#         0.16059096, 0.16325542, 0.16572148, 0.16800642, 0.17012659,
#         0.17209735, 0.17393301, 0.17564683, 0.17725101, 0.17875674,
#         0.18017425, 0.18151283, 0.18278093, 0.18398619, 0.18513551,
#         0.18623509, 0.18729052, 0.18830684, 0.18928855, 0.19023967,
#         0.19116383, 0.19206425, 0.19294382, 0.19380512, 0.19465044,
#         0.19548184, 0.19630115, 0.19711   , 0.19790983, 0.19870195,
#         0.19948751, 0.20026752, 0.20104291, 0.20181449, 0.20258298,
#         0.20334903, 0.20411321, 0.20487603, 0.20563794, 0.20639936,
#         0.20716063, 0.20792209, 0.20868402, 0.20944668, 0.21021029,
#         0.21097507, 0.21174118, 0.21250879, 0.21327805, 0.2140491 ,
#         0.21482204, 0.21559698, 0.21637401, 0.21715323, 0.2179347 ,
# ...
